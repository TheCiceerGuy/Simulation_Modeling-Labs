# %% [markdown]
# <a href="https://colab.research.google.com/github/TheCiceerGuy/Simulation_Modeling-Labs/blob/main/Monte_Carlo_Simulation%3A%20Calculating%20Value%20of%20PI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Monte Carlo Simulation Example:**

# %% [markdown]
# *Example-1: Estimating the value of π:*

# %% [markdown]
# ***Sample Points = 100***

# %%
import numpy as np
import matplotlib.pyplot as plt

def monte_carlo_pi(num_samples):
    x = np.random.uniform(-1, 1, num_samples)
    y = np.random.uniform(-1, 1, num_samples)

    distance = np.sqrt(x**2 + y**2)

    inside_circle = np.sum(distance <= 1)

    pi_estimate = (inside_circle / num_samples) * 4

    return inside_circle, pi_estimate

num_samples = 100

inside_circle, pi_estimate = monte_carlo_pi(num_samples)

print(f"Points inside the circle: {inside_circle}")
print(f"Estimated value of π with {num_samples} samples: {pi_estimate}")
x = np.random.uniform(-1, 1, num_samples)
y = np.random.uniform(-1, 1, num_samples)
plt.figure(figsize=(6, 6))
plt.scatter(x, y, c=np.sqrt(x**2 + y**2) <= 1, cmap='bwr', s=1)
plt.gca().set_aspect('equal', adjustable='box')
plt.title('Monte Carlo Simulation for π')
plt.xlabel('x')
plt.ylabel('y')
plt.show()
# Out:
# Points inside the circle: 75
# Estimated value of π with 100 samples: 3.0

# %% [markdown]
# ***Sample Points = 1000***

# %%
import numpy as np
import matplotlib.pyplot as plt

def monte_carlo_pi(num_samples):
    x = np.random.uniform(-1, 1, num_samples)
    y = np.random.uniform(-1, 1, num_samples)

    distance = np.sqrt(x**2 + y**2)

    inside_circle = np.sum(distance <= 1)

    pi_estimate = (inside_circle / num_samples) * 4

    return inside_circle, pi_estimate

num_samples = 1000

inside_circle, pi_estimate = monte_carlo_pi(num_samples)

print(f"Points inside the circle: {inside_circle}")
print(f"Estimated value of π with {num_samples} samples: {pi_estimate}")
x = np.random.uniform(-1, 1, num_samples)
y = np.random.uniform(-1, 1, num_samples)
plt.figure(figsize=(6, 6))
plt.scatter(x, y, c=np.sqrt(x**2 + y**2) <= 1, cmap='bwr', s=1)
plt.gca().set_aspect('equal', adjustable='box')
plt.title('Monte Carlo Simulation for π')
plt.xlabel('x')
plt.ylabel('y')
plt.show()
# Out:
# Points inside the circle: 792
# Estimated value of π with 1000 samples: 3.168

# %% [markdown]
# ***Sample Points = 10000***

# %%
import numpy as np
import matplotlib.pyplot as plt

def monte_carlo_pi(num_samples):
    x = np.random.uniform(-1, 1, num_samples)
    y = np.random.uniform(-1, 1, num_samples)

    distance = np.sqrt(x**2 + y**2)

    inside_circle = np.sum(distance <= 1)

    pi_estimate = (inside_circle / num_samples) * 4

    return inside_circle, pi_estimate

num_samples = 10000

inside_circle, pi_estimate = monte_carlo_pi(num_samples)

print(f"Points inside the circle: {inside_circle}")
print(f"Estimated value of π with {num_samples} samples: {pi_estimate}")
x = np.random.uniform(-1, 1, num_samples)
y = np.random.uniform(-1, 1, num_samples)
plt.figure(figsize=(6, 6))
plt.scatter(x, y, c=np.sqrt(x**2 + y**2) <= 1, cmap='bwr', s=1)
plt.gca().set_aspect('equal', adjustable='box')
plt.title('Monte Carlo Simulation for π')
plt.xlabel('x')
plt.ylabel('y')
plt.show()
# Out:
# Points inside the circle: 7933
# Estimated value of π with 10000 samples: 3.1732

# %% [markdown]
# ***Sample Points = 100000***

# %%
import numpy as np
import matplotlib.pyplot as plt

def monte_carlo_pi(num_samples):
    x = np.random.uniform(-1, 1, num_samples)
    y = np.random.uniform(-1, 1, num_samples)

    distance = np.sqrt(x**2 + y**2)

    inside_circle = np.sum(distance <= 1)

    pi_estimate = (inside_circle / num_samples) * 4

    return inside_circle, pi_estimate

num_samples = 100000

inside_circle, pi_estimate = monte_carlo_pi(num_samples)

print(f"Points inside the circle: {inside_circle}")
print(f"Estimated value of π with {num_samples} samples: {pi_estimate}")
x = np.random.uniform(-1, 1, num_samples)
y = np.random.uniform(-1, 1, num_samples)
plt.figure(figsize=(6, 6))
plt.scatter(x, y, c=np.sqrt(x**2 + y**2) <= 1, cmap='bwr', s=1)
plt.gca().set_aspect('equal', adjustable='box')
plt.title('Monte Carlo Simulation for π')
plt.xlabel('x')
plt.ylabel('y')
plt.show()
# Out:
# Points inside the circle: 78277
# Estimated value of π with 100000 samples: 3.13108
